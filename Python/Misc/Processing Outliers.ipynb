# %%
def detect_discrete_outliers(data, types, threshold):
    data.dropna(inplace = True)
    
    if types == "IQR":
        Q1 = data.quantile(0.25)
        Q3 = data.quantile(0.75)
        IQR = Q3 - Q1
        mask1 = Q1 - 1.5 * IQR
        mask2 = Q3 + 1.5 * IQR
        outliers = (data < mask1) & (data > mask2)
    elif types == "Z":
        mean = data.mean()
        std = data.std()
        z_score = (data - mean)/std 
        outliers = abs(z_score) > threshold
    else:
        raise Warning("Only 2 types: IQR or Z")

    return outliers

def clean_outliers(data, types = "IQR", threshold = 3):
    '''
    This function will cleanse outliers only
    and leave missing values alone.
    '''
    df = data.copy()
    list_of_outliers = [False]*df.shape[0]
    for x in df:
        list_of_outliers |= detect_discrete_outliers(df[x], types, 3)
    list_of_outliers
    return df[-list_of_outliers]

# %%
# Create test data
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(100).reshape(20,5), index=range(5,25))

df.iloc[5,3] = np.nan
df.iloc[8,2] = np.nan
df.iloc[11,1] = np.nan

df.iloc[4,1] = 10
df.iloc[6,2] = 15
df.iloc[19,4] = 33

df
# Out:
#            0          1          2         3          4
# 5  -0.057320  -0.071192   0.440447 -1.812297   1.069912
# 6   0.378565   1.535975  -2.275993 -0.768625  -0.869030
# 7  -0.637205   1.369349  -0.797095  0.728448   0.238891
# 8  -1.331737   1.181629  -1.992896 -1.349648  -0.049244
# 9  -1.368368  10.000000   1.849274 -0.169103   0.274129
# 10  0.484604  -1.194556  -0.497964       NaN   0.971353
# 11  0.453539   1.530541  15.000000  0.706543   0.077578
# 12 -1.243120  -1.355744  -0.392365  1.647200   0.590740
# 13 -0.129433  -0.905226        NaN  0.034212  -0.492850
# 14 -0.673350   1.099022   0.993498 -0.514717   0.074182
# 15  0.167817  -0.865028  -0.714394 -0.741785  -0.717694
# 16  0.761206        NaN  -0.345373 -0.339030   1.085080
# 17  0.875249   0.728317  -1.436609 -1.146028  -0.882287
# 18 -0.155430   0.899931  -1.700926 -0.643827   0.591427
# 19 -0.634757  -0.418361   0.100072 -1.199520   0.191089
# 20 -1.849107  -1.411340  -0.969327 -1.100697   1.182230
# 21 -2.206753  -0.389659   0.049531  0.468960   2.206244
# 22 -0.454196   1.784027  -0.754071 -1.283399  -0.766213
# 23  2.667114  -0.957648   0.654852  0.598036  -0.329995
# 24  0.337849   1.588912   0.644892  0.142586  33.000000

# %%
clean_outliers(data=df, types = "IQR")
# Out:
#            0          1          2         3          4
# 5  -0.057320  -0.071192   0.440447 -1.812297   1.069912
# 6   0.378565   1.535975  -2.275993 -0.768625  -0.869030
# 7  -0.637205   1.369349  -0.797095  0.728448   0.238891
# 8  -1.331737   1.181629  -1.992896 -1.349648  -0.049244
# 9  -1.368368  10.000000   1.849274 -0.169103   0.274129
# 10  0.484604  -1.194556  -0.497964       NaN   0.971353
# 11  0.453539   1.530541  15.000000  0.706543   0.077578
# 12 -1.243120  -1.355744  -0.392365  1.647200   0.590740
# 13 -0.129433  -0.905226        NaN  0.034212  -0.492850
# 14 -0.673350   1.099022   0.993498 -0.514717   0.074182
# 15  0.167817  -0.865028  -0.714394 -0.741785  -0.717694
# 16  0.761206        NaN  -0.345373 -0.339030   1.085080
# 17  0.875249   0.728317  -1.436609 -1.146028  -0.882287
# 18 -0.155430   0.899931  -1.700926 -0.643827   0.591427
# 19 -0.634757  -0.418361   0.100072 -1.199520   0.191089
# 20 -1.849107  -1.411340  -0.969327 -1.100697   1.182230
# 21 -2.206753  -0.389659   0.049531  0.468960   2.206244
# 22 -0.454196   1.784027  -0.754071 -1.283399  -0.766213
# 23  2.667114  -0.957648   0.654852  0.598036  -0.329995
# 24  0.337849   1.588912   0.644892  0.142586  33.000000

# %%
clean_outliers(data=df, types = "Z", threshold=3)
# Out:
#            0         1         2         3         4
# 5  -0.057320 -0.071192  0.440447 -1.812297  1.069912
# 6   0.378565  1.535975 -2.275993 -0.768625 -0.869030
# 7  -0.637205  1.369349 -0.797095  0.728448  0.238891
# 8  -1.331737  1.181629 -1.992896 -1.349648 -0.049244
# 10  0.484604 -1.194556 -0.497964       NaN  0.971353
# 12 -1.243120 -1.355744 -0.392365  1.647200  0.590740
# 13 -0.129433 -0.905226       NaN  0.034212 -0.492850
# 14 -0.673350  1.099022  0.993498 -0.514717  0.074182
# 15  0.167817 -0.865028 -0.714394 -0.741785 -0.717694
# 16  0.761206       NaN -0.345373 -0.339030  1.085080
# 17  0.875249  0.728317 -1.436609 -1.146028 -0.882287
# 18 -0.155430  0.899931 -1.700926 -0.643827  0.591427
# 19 -0.634757 -0.418361  0.100072 -1.199520  0.191089
# 20 -1.849107 -1.411340 -0.969327 -1.100697  1.182230
# 21 -2.206753 -0.389659  0.049531  0.468960  2.206244
# 22 -0.454196  1.784027 -0.754071 -1.283399 -0.766213
# 23  2.667114 -0.957648  0.654852  0.598036 -0.329995

# %%
clean_outliers(data=df, types = "I", threshold=3)
# Out:
# ---------------------------------------------------------------------------
# Warning                                   Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 clean_outliers(data=df, types = "I", threshold=3)
#
# Cell In[1], line 29, in clean_outliers(data, types, threshold)
#      27 list_of_outliers = [False]*df.shape[0]
#      28 for x in df:
# ---> 29     list_of_outliers |= detect_discrete_outliers(df[x], types, 3)
#      30 list_of_outliers
#      31 return df[-list_of_outliers]
#
# Cell In[1], line 17, in detect_discrete_outliers(data, types, threshold)
#      15     outliers = abs(z_score) > threshold
#      16 else:
# ---> 17     raise Warning("Only 2 types: IQR or Z")
#      19 return outliers
#
# Warning: Only 2 types: IQR or Z
